# %% [markdown]
# CLASE PYTHON BOOTCAMP

# %%
print ('hello world')
# Out:
# hello world

# %% [markdown]
# ##  VARIABLE

# %%
nombre = "Rorro"
print (nombre)

apellido = "Arguello"
print (apellido)

# %% [markdown]
#  ## TIPOS DE TEXTO

# %%
nombre =  "Rodri"  #string - str 
altura = 1.75 #decimal - float
edad = 18 #numero entero - int 
feliz = True # bool 


print (nombre)
print (altura)
print (edad)
print (feliz)

print (nombre, edad , altura, feliz)
# Out:
# Rodri
# 1.75
# 18
# True
# Rodri 18 1.75 True

# %% [markdown]
# ## CHALLENGE

# %%
nombre = "Rorro"
edad = 18 
ciudad = "Asuncion"

print (nombre, edad , ciudad)
# Out:
# Rorro 18 Asuncion

# %% [markdown]
# ## OPERACIONES ARITMETICAS

# %%
print (3%2) # % Esto es el resto, es lo que sobra
# Out:
# 1

# %%
producto1 = "Papas"
costo1 = 10000
producto2 = "Coca cola"
costo2 = 8000
billetera = 50000

total_gastado = costo1 + costo2
vuelto = billetera - total_gastado
print (total_gastado)
print (f""{total_gastado})
print (f"Tu vuelto va a ser"{vuelto})

# %%
##  CHALLENGE

# %%
manzanas = 30
naranjas = 30
total = manzanas + naranjas 
print ("Las frutas vendidas van a ser: ", total)  


frutas_vendidas = 20
restante = total - frutas_vendidas 

print ("Las frutas restantes van a ser: ", restante)
# Out:
# Las frutas vendidas van a ser:  60
# Las frutas restantes van a ser:  40

# %% [markdown]
# ## CONCATENAR

# %%
nombre = "Rodrigo"
apellido = "Arguello"

print ("Hola, mi nombre es", nombre + " " + apellido)
# Out:
# Hola mi nombre es Rodrigo Arguello

# %%
nombre =  "Sebasthian"
apellido = "Lopez"

print(f"Hola, me llamo {nombre} {apellido} tengo 19 anhos ") #meter una variable dentro del texto
# Out:
# Hola, me llamo Sebasthian Lopez tengo 19 anhos

# %%
nombre = input("Ingrese su nombre:")
apellido = input("Ingrese su apellido:")

print (f"Hola {nombre} {apellido}. Que tal estas?")

# %%
edad = 30
print (type(edad))

edad = '30'
print (type(edad))

edad = 30.1
print (type(edad))

edad = True 
print (type(edad))

# type es para ver que es tu variable si int, str, float o bool
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
frutas = int(input("Cuantas frutas tenes?"))
vendidas = int(input("Cuantas frutas vendiste?"))
restante = frutas - vendidas
print (restante)

# %% [markdown]
# CHALLENGE

# %%
num1 = int(input("Ingrese un numero:"))
num2 = int(input("Ingrese un numero:")) 
suma = num1 + num2 

print (f"La suma de los numeros es {suma}")
# Out:
# La suma de los numeros es 5

# %% [markdown]
#  ## FUNCIONES

# %%
def saludo (): 
    nombre = input("Ingrese su nombre: ")
    apellido = input("Ingrese su apellido: ")
    print (f"Hola {nombre} {apellido}. Bienvenido al bootcamp!!" )
saludo ()  #si repito la funcion llama devuelta y me pide devuelta los datos, no importa si esta en otro bloque
#igual llama a la funcion
# Out:
# Hola Rorro Arguello. Bienvenido al bootcamp!!

# %%
def inicio ():
    nombre = input ("Cual es tu nombre? ")
    apellido = input ("Cual es tu apellido?")
    edad = int( input ("Cual es tu edad")) 
    objetivo =  input ("Cual es tu objetivo con este bootcamp") 
    print (f"Hola mi nombre es {nombre} {apellido} tengo {edad} anhos y mi objetivo con este bootcamp es {objetivo}")
inicio()
inicio()
inicio()

# %% [markdown]
# ## PARAMETROS Y ARGUMENTOS

# %%
def preparar (ingredientes): 
    print ("Cortar el pan")
    print ("Colocar mayonesa")
    print (f"Colocar {ingredientes}")
    print ("Colocar queso")
    print ("Colocar tomate")
    print ("Colocar lechuga")

preparar ()

# %%
def saludar (nombre, apellido): # Parametro - Es la puerta de la casa 
    print ("Hola", nombre, apellido)
    
saludar ("Rodrigo", "Arguello")  #Argumentos - Es el valor que ingreza a la casa
# Out:
# Hola Rodrigo Arguello

# %%
def sumar (num1, num2):
    calcular = num1 + num2
    print (calcular)
sumar (70, 30)
# Out:
# 100

# %% [markdown]
# CHALLENGE

# %%
def elemento (reloj, marca,costo): 
    print (f"Mi reloj es {reloj} de la marca {marca} y tuvo un costo de {costo}")
elemento ("digital", "Haylou","300.000")
# Out:
# Mi reloj es digital de la marca Haylou y tuvo un costo de 300.000

# %%
def elemento (reloj, marca,costo): 
    print (f"Mi reloj es {reloj} de la marca {marca} y tuvo un costo de {costo}")
elemento (input ("Su reloj es digital o analogico?"), 
        input ("Que marca es su reloj?"),
        input ("Cual es el costo de reloj?"))

# %%
ingredientes = 'Jamon'  # VARIABLE GLOBAL
# si la variabel sale de la burbuja de la funcion puedo utilizar en otra parte de codigo pero si coloco dentro no funciona afuera de la funcion creada 
def prep (): 
    ingredientes = 'Queso' #VARIABLE LOCAL 
    print (f'Estoy usando {ingredientes}')   
prep () 

print (ingredientes)
# Out:
# Estoy usando Queso
# Jamon
